# %% [markdown]
# ## Risk Prediction
# ### Análise exploratória dos dados de clientes de Caratão de crédito
#
# Dados: https://archive.ics.uci.edu/ml/datasets/default+of+credit+card+clients#

# %% [markdown]
# ### 1. Resumo
#
# O objetivo deste Notebook é explorar os dados, criar visualizações que facilitem o entendimento, analizar as informações do link acima e Traduzir o nomes das variáveis com a finalidade de melhor entendimento.
# Ao fim tentaremos responmder:
#  1. Quantos registros(linhas) existem nos dados?
#  2. Quantas Colunas existem?
#  3. Existem valores Nulos?
#      * se sim qual ação deve ser tomada?
#  4. Existem valores Duplicados?
#      * se sim qual ação deve ser tomada?
#  5. Qual a classificação das variáveis?
#      * há necessicade de alterar o tipo das variáveis?
#  6. Qual a distribuição das variáveis Nominais?
#  7. Qual a distribuição das demais variáveis?
#  8. Qual é o Predito e quais são os candidatos a preditores?
#  9. Os dados estão balanceados?
#  10. Quais os possíveis preditores podem ser criados?
#
# ______________

# %% [markdown]
# ### 2 Implementação
# #### 2.1 Importação das Bibilotecas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import HTML
#from pandas_profiling import ProfileReport

pd.options.display.max_columns = None
pd.set_option('max_colwidth', 400)
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# * Se necessário usar os comandos abaixo para instalar estas bibliotecas
# ~~~ Python
# # !poetry add xlrd
# # !poetry add pandas-profiling[notebook]
# ~~~

# %% [markdown]
# ___________________
# #### 2.2 Carga dos Dados

# %%
df = pd.read_excel("../data/raw/default of credit card clients.xls", header=1)
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  \
# 0     -2     -2       3913       3102        689          0          0
# 1      0      2       2682       1725       2682       3272       3455
# 2      0      0      29239      14027      13559      14331      14948
# 3      0      0      46990      48233      49291      28314      28959
# 4      0      0       8617       5670      35835      20940      19146
#
#    BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0          0         0       689         0         0         0         0
# 1       3261         0      1000      1000      1000         0      2000
# 2      15549      1518      1500      1000      1000      1000      5000
# 3      29547      2000      2019      1200      1100      1069      1000
# 4      19131      2000     36681     10000      9000       689       679
#
#    default payment next month
# 0                           1
# 1                           1
# 2                           0
# 3                           0
# 4                           0

# %% [markdown]
# * Percebemos:
# Que as colunas estão nomeadas como X1, X2....
# Que a Coluna "unnamed: 0" repete o index.

# %% [markdown]
# _________________
# #### 2.3 Criando o dicionário de Dados
# O dicionário de dados contém o nome das colunas, o nome traduzido e a descrição que constava no "Data Set Information" do site.

# %%
dicionario = df.columns.to_frame(name="Colunas").reset_index(drop=True)
dicionario["Col_Trad"] = [
    "ID",
    "limite",
    "sexo",
    "educacao",
    "estado_civil",
    "idade",
    "status_0509",
    "status_0508",
    "status_0507",
    "status_0506",
    "status_0505",
    "status_0504",
    "saldo_0509",
    "saldo_0508",
    "saldo_0507",
    "saldo_0506",
    "saldo_0505",
    "saldo_0504",
    "pago_0509",
    "pago_0508",
    "pago_0507",
    "pago_0506",
    "pago_0505",
    "pago_0504",
    "mau"]
dicionario["Descrição"] = [
    "ID",
    "Limte de Crédito",
    "(1 = masculino; 2 = feminino)",
    "Educação (1 = pós-graduação; 2 = universidade; 3 = ensino médio; 4 = outros)",
    "Estado civil (1 = casado; 2 = solteiro; 3 = outros)",
    "Idade",
    "status de pagamentos em set/2005: -1 = pago devidamente; 1 = atraso de um mês; 2 = atraso de dois meses; . . .; 8 = atraso de oito meses; 9 = atraso de nove meses ou mais",
    "status de pagamentos em ago/2005: -1 = pago devidamente; 1 = atraso de um mês; 2 = atraso de dois meses; . . .; 8 = atraso de oito meses; 9 = atraso de nove meses ou mais",
    "status de pagamentos em jul/2005: -1 = pago devidamente; 1 = atraso de um mês; 2 = atraso de dois meses; . . .; 8 = atraso de oito meses; 9 = atraso de nove meses ou mais",
    "status de pagamentos em jun/2005: -1 = pago devidamente; 1 = atraso de um mês; 2 = atraso de dois meses; . . .; 8 = atraso de oito meses; 9 = atraso de nove meses ou mais",
    "status de pagamentos em mai/2005: -1 = pago devidamente; 1 = atraso de um mês; 2 = atraso de dois meses; . . .; 8 = atraso de oito meses; 9 = atraso de nove meses ou mais",
    "status de pagamentos em abr/2005: -1 = pago devidamente; 1 = atraso de um mês; 2 = atraso de dois meses; . . .; 8 = atraso de oito meses; 9 = atraso de nove meses ou mais",
    "Saldo em set/2005",
    "Saldo em ago/2005",
    "Saldo em jul/2005",
    "Saldo em jun/2005",
    "Saldo em mai/2005",
    "Saldo em abr/2005",
    "Valor pago em set/2005",
    "Valor pago em ago/2005",
    "Valor pago em jul/2005",
    "Valor pago em jun/2005",
    "Valor pago em mai/2005",
    "Valor pago  em abr/2005",
    "Pagamento próximo mês (Sim = 1, Não = 0)"]

dicionario
# Out:
#                        Colunas      Col_Trad  \
# 0                           ID            ID
# 1                    LIMIT_BAL        limite
# 2                          SEX          sexo
# 3                    EDUCATION      educacao
# 4                     MARRIAGE  estado_civil
# 5                          AGE         idade
# 6                        PAY_0   status_0509
# 7                        PAY_2   status_0508
# 8                        PAY_3   status_0507
# 9                        PAY_4   status_0506
# 10                       PAY_5   status_0505
# 11                       PAY_6   status_0504
# 12                   BILL_AMT1    saldo_0509
# 13                   BILL_AMT2    saldo_0508
# 14                   BILL_AMT3    saldo_0507
# 15                   BILL_AMT4    saldo_0506
# 16                   BILL_AMT5    saldo_0505
# 17                   BILL_AMT6    saldo_0504
# 18                    PAY_AMT1     pago_0509
# 19                    PAY_AMT2     pago_0508
# 20                    PAY_AMT3     pago_0507
# 21                    PAY_AMT4     pago_0506
# 22                    PAY_AMT5     pago_0505
# 23                    PAY_AMT6     pago_0504
# 24  default payment next month           mau
#
#                                                                                                                                                                      Descrição
# 0                                                                                                                                                                           ID
# 1                                                                                                                                                             Limte de Crédito
# 2                                                                                                                                                (1 = masculino; 2 = feminino)
# 3                                                                                                 Educação (1 = pós-graduação; 2 = universidade; 3 = ensino médio; 4 = outros)
# 4                                                                                                                          Estado civil (1 = casado; 2 = solteiro; 3 = outros)
# 5                                                                                                                                                                        Idade
# 6   status de pagamentos em set/2005: -1 = pago devidamente; 1 = atraso de um mês; 2 = atraso de dois meses; . . .; 8 = atraso de oito meses; 9 = atraso de nove meses ou mais
# 7   status de pagamentos em ago/2005: -1 = pago devidamente; 1 = atraso de um mês; 2 = atraso de dois meses; . . .; 8 = atraso de oito meses; 9 = atraso de nove meses ou mais
# 8   status de pagamentos em jul/2005: -1 = pago devidamente; 1 = atraso de um mês; 2 = atraso de dois meses; . . .; 8 = atraso de oito meses; 9 = atraso de nove meses ou mais
# 9   status de pagamentos em jun/2005: -1 = pago devidamente; 1 = atraso de um mês; 2 = atraso de dois meses; . . .; 8 = atraso de oito meses; 9 = atraso de nove meses ou mais
# 10  status de pagamentos em mai/2005: -1 = pago devidamente; 1 = atraso de um mês; 2 = atraso de dois meses; . . .; 8 = atraso de oito meses; 9 = atraso de nove meses ou mais
# 11  status de pagamentos em abr/2005: -1 = pago devidamente; 1 = atraso de um mês; 2 = atraso de dois meses; . . .; 8 = atraso de oito meses; 9 = atraso de nove meses ou mais
# 12                                                                                                                                                           Saldo em set/2005
# 13                                                                                                                                                           Saldo em ago/2005
# 14                                                                                                                                                           Saldo em jul/2005
# 15                                                                                                                                                           Saldo em jun/2005
# 16                                                                                                                                                           Saldo em mai/2005
# 17                                                                                                                                                           Saldo em abr/2005
# 18                                                                                                                                                      Valor pago em set/2005
# 19                                                                                                                                                      Valor pago em ago/2005
# 20                                                                                                                                                      Valor pago em jul/2005
# 21                                                                                                                                                      Valor pago em jun/2005
# 22                                                                                                                                                      Valor pago em mai/2005
# 23                                                                                                                                                     Valor pago  em abr/2005
# 24                                                                                                                                    Pagamento próximo mês (Sim = 1, Não = 0)

# %%
dicionario.to_csv("../references/dicionario_dados.csv", index=False)

# %% [markdown]
# Salvando o dicionário na pasta de referências

# %% [markdown]
# *********************************
# ### 3 Analise preliminar
# #### 3.1 Informações básicas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
#  13  BILL_AMT2                   30000 non-null  int64
#  14  BILL_AMT3                   30000 non-null  int64
#  15  BILL_AMT4                   30000 non-null  int64
#  16  BILL_AMT5                   30000 non-null  int64
#  17  BILL_AMT6                   30000 non-null  int64
#  18  PAY_AMT1                    30000 non-null  int64
#  19  PAY_AMT2                    30000 non-null  int64
#  20  PAY_AMT3                    30000 non-null  int64
#  21  PAY_AMT4                    30000 non-null  int64
#  22  PAY_AMT5                    30000 non-null  int64
#  23  PAY_AMT6                    30000 non-null  int64
#  24  default payment next month  30000 non-null  int64
# dtypes: int64(25)
# memory usage: 5.7 MB

# %% [markdown]
# OBS.: Todas as linhas possuem a mesma contagem e todas são do tipo object(String)

# %% [markdown]
# _________________
# #### 3.2 Quantos registros (linhas) e Colunas existem nos dados?

# %%
linhas = df.shape[0]
colunas = df.shape[1]

display(HTML(f'<h5> O Data Frame possui <span style="color:red">{linhas}</span> linhas e <span style="color:red">{colunas}</span> Colunas.</h5>'))
# Out:
# <h5> O Data Frame possui <span style="color:red">30000</span> linhas e <span style="color:red">25</span> Colunas.</h5>

# %% [markdown]
# ____________________
# #### 3.3 Existem Valores Nulos?
#  * se sim qual ação deve ser tomada?

# %%
df.isnull().sum().to_frame(name = "Soma de Nulos por variável")
# Out:
#                             Soma de Nulos por variável
# ID                                                   0
# LIMIT_BAL                                            0
# SEX                                                  0
# EDUCATION                                            0
# MARRIAGE                                             0
# AGE                                                  0
# PAY_0                                                0
# PAY_2                                                0
# PAY_3                                                0
# PAY_4                                                0
# PAY_5                                                0
# PAY_6                                                0
# BILL_AMT1                                            0
# BILL_AMT2                                            0
# BILL_AMT3                                            0
# BILL_AMT4                                            0
# BILL_AMT5                                            0
# BILL_AMT6                                            0
# PAY_AMT1                                             0
# PAY_AMT2                                             0
# PAY_AMT3                                             0
# PAY_AMT4                                             0
# PAY_AMT5                                             0
# PAY_AMT6                                             0
# default payment next month                           0

# %%
tot_nulos = df.isnull().sum().sum()
display(HTML(f'<h5> A quantidade total de nulos do data frame é: <span style="color:red">{tot_nulos}</span> registros.</h5>'))
# Out:
# <h5> A quantidade total de nulos do data frame é: <span style="color:red">0</span> registros.</h5>

# %% [markdown]
# ____________
# ####  3.4 Existem valores Duplicados?
#      * se sim qual ação deve ser tomada?

# %%
duplicados = df['ID'].duplicated()
duplicados = duplicados.sum()
display(HTML(f'<h5> O Data Frame possui <span style="color:red">{duplicados}</span> valores duplicados.</h5>'))
# Out:
# <h5> O Data Frame possui <span style="color:red">0</span> valores duplicados.</h5>

# %% [markdown]
# __________
# #### 3.5 Qual a classificação das variáveis?
#      * há necessicade de alterar o tipo das variáveis?

# %% [markdown]
# **Inuteis:**
#   ID
#
#  * Optou-se por excluir a vareável ID

# %%
df.pop("ID")
df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  \
# 0     -2     -2       3913       3102        689          0          0
# 1      0      2       2682       1725       2682       3272       3455
# 2      0      0      29239      14027      13559      14331      14948
# 3      0      0      46990      48233      49291      28314      28959
# 4      0      0       8617       5670      35835      20940      19146
#
#    BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0          0         0       689         0         0         0         0
# 1       3261         0      1000      1000      1000         0      2000
# 2      15549      1518      1500      1000      1000      1000      5000
# 3      29547      2000      2019      1200      1100      1069      1000
# 4      19131      2000     36681     10000      9000       689       679
#
#    default payment next month
# 0                           1
# 1                           1
# 2                           0
# 3                           0
# 4                           0

# %% [markdown]
# **Nominais:**
# * Apesar da variável "education" normalmente ser classificada como qualitativa ordinal, neste caso decidimos classificar como nominal pois o grupo "outros" poderia conter tanto analfabeto e ensino fundamental quanto mestrado e doutorado quebrando assim a relação de ordenação.

# %%
sex = {1: "masculino", 2: "feminino"}
education = {1: "pós-graduação", 2: "universidade", 3: "ensino médio", 4: "outros"}
mariage = {1: "casado", 2: "solteiro", 3: "outros"}

# %% [markdown]
# **Ordinais:**

# %%
var_ordinais = ['LIMIT_BAL', 'AGE', 'PAY_0', 'PAY_2',
                   'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
                   'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
                   'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']

# %% [markdown]
# **Binárias:**
#
# 'default payment next month'

# %%
mau = {0: "nao", 1: "sim"}

# %% [markdown]
# _____________
# #### 4 Correção do tipo
# **Variáveis numéricas**

# %%
# Criando uma cópia para comparação
df_orig = df.copy()

# %%
df[var_ordinais] = df[var_ordinais].astype(int)

# %% [markdown]
# **variáveis categóricas e Binárias:**

# %%
df["SEX"] = df["SEX"].map(sex)
df["EDUCATION"] = df["EDUCATION"].map(education)
df["MARRIAGE"] = df["MARRIAGE"].map(mariage)
df['default payment next month'] = df['default payment next month'].map(mau)
df.head()
# Out:
#    LIMIT_BAL        SEX     EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0      20000   feminino  universidade    casado   24      2      2     -1
# 1     120000   feminino  universidade  solteiro   26     -1      2      0
# 2      90000   feminino  universidade  solteiro   34      0      0      0
# 3      50000   feminino  universidade    casado   37      0      0      0
# 4      50000  masculino  universidade    casado   57     -1      0     -1
#
#    PAY_4  PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  \
# 0     -1     -2     -2       3913       3102        689          0          0
# 1      0      0      2       2682       1725       2682       3272       3455
# 2      0      0      0      29239      14027      13559      14331      14948
# 3      0      0      0      46990      48233      49291      28314      28959
# 4      0      0      0       8617       5670      35835      20940      19146
#
#    BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0          0         0       689         0         0         0         0
# 1       3261         0      1000      1000      1000         0      2000
# 2      15549      1518      1500      1000      1000      1000      5000
# 3      29547      2000      2019      1200      1100      1069      1000
# 4      19131      2000     36681     10000      9000       689       679
#
#   default payment next month
# 0                        sim
# 1                        sim
# 2                        nao
# 3                        nao
# 4                        nao

# %% [markdown]
# ____________
# ### 5 Traduz Colunas

# %%
df.columns = dicionario['Col_Trad'].to_list()[1:]
df
# Out:
#        limite       sexo      educacao estado_civil  idade  status_0509  \
# 0       20000   feminino  universidade       casado     24            2
# 1      120000   feminino  universidade     solteiro     26           -1
# 2       90000   feminino  universidade     solteiro     34            0
# 3       50000   feminino  universidade       casado     37            0
# 4       50000  masculino  universidade       casado     57           -1
# ...       ...        ...           ...          ...    ...          ...
# 29995  220000  masculino  ensino médio       casado     39            0
# 29996  150000  masculino  ensino médio     solteiro     43           -1
# 29997   30000  masculino  universidade     solteiro     37            4
# 29998   80000  masculino  ensino médio       casado     41            1
# 29999   50000  masculino  universidade       casado     46            0
#
#        status_0508  status_0507  status_0506  status_0505  status_0504  \
# 0                2           -1           -1           -2           -2
# 1                2            0            0            0            2
# 2                0            0            0            0            0
# 3                0            0            0            0            0
# 4                0           -1            0            0            0
# ...            ...          ...          ...          ...          ...
# 29995            0            0            0            0            0
# 29996           -1           -1           -1            0            0
# 29997            3            2           -1            0            0
# 29998           -1            0            0            0           -1
# 29999            0            0            0            0            0
#
#        saldo_0509  saldo_0508  saldo_0507  saldo_0506  saldo_0505  saldo_0504  \
# 0            3913        3102         689           0           0           0
# 1            2682        1725        2682        3272        3455        3261
# 2           29239       14027       13559       14331       14948       15549
# 3           46990       48233       49291       28314       28959       29547
# 4            8617        5670       35835       20940       19146       19131
# ...           ...         ...         ...         ...         ...         ...
# 29995      188948      192815      208365       88004       31237       15980
# 29996        1683        1828        3502        8979        5190           0
# 29997        3565        3356        2758       20878       20582       19357
# 29998       -1645       78379       76304       52774       11855       48944
# 29999       47929       48905       49764       36535       32428       15313
#
#        pago_0509  pago_0508  pago_0507  pago_0506  pago_0505  pago_0504  mau
# 0              0        689          0          0          0          0  sim
# 1              0       1000       1000       1000          0       2000  sim
# 2           1518       1500       1000       1000       1000       5000  nao
# 3           2000       2019       1200       1100       1069       1000  nao
# 4           2000      36681      10000       9000        689        679  nao
# ...          ...        ...        ...        ...        ...        ...  ...
# 29995       8500      20000       5003       3047       5000       1000  nao
# 29996       1837       3526       8998        129          0          0  nao
# 29997          0          0      22000       4200       2000       3100  sim
# 29998      85900       3409       1178       1926      52964       1804  sim
# 29999       2078       1800       1430       1000       1000       1000  sim
#
# [30000 rows x 24 columns]

# %% [markdown]
# __________
# ### 6 Pandas Profiling

# %%
#profile = ProfileReport(df, title="Pandas Profiling Report - DATA GEAR", explorative=True)
#profile

# %% [markdown]
# Salvar o report inicial

# %%
#profile.to_file("../references/Report_inicial.html")

# %% [markdown]
# __________
# ### 7 Análise

# %%
# procurando novamente por valores faltantes após renomear campos
df.isnull().sum().to_frame(name = "Soma de Nulos")
# Out:
#               Soma de Nulos
# limite                    0
# sexo                      0
# educacao                345
# estado_civil             54
# idade                     0
# status_0509               0
# status_0508               0
# status_0507               0
# status_0506               0
# status_0505               0
# status_0504               0
# saldo_0509                0
# saldo_0508                0
# saldo_0507                0
# saldo_0506                0
# saldo_0505                0
# saldo_0504                0
# pago_0509                 0
# pago_0508                 0
# pago_0507                 0
# pago_0506                 0
# pago_0505                 0
# pago_0504                 0
# mau                       0

# %%
# buscando nos daos originais o motivo dos nulos
df_orig['MARRIAGE'].value_counts()
# Out:
# 2    15964
# 1    13659
# 3      323
# 0       54
# Name: MARRIAGE, dtype: int64

# %% [markdown]
# * Existem <span style="color:red">54</span> valores registrados como código <span style="color:red">0</span>, código que não havia na descrição dos dados.
# Avaliar a possibilidade de incluír junto a outrtos(código = 3)

# %%
df_orig['EDUCATION'].value_counts().sort_index()
# Out:
# 0       14
# 1    10585
# 2    14030
# 3     4917
# 4      123
# 5      280
# 6       51
# Name: EDUCATION, dtype: int64

# %% [markdown]
#  * Encontramos <span style="color:red">345</span> dados classificados nos códigos 0, 5 e 6. Verificamos que trata-se de dados classificados com códigos que não constavam na descrição dos dados no site da UCI.
# Avaliar a possibilidade de incluír junto a outrtos(código = 4)

# %% [markdown]
# _____________
# ### 8 .Correção dos dados
# Transformaremos os nulos em "outros" e logo depois analizaremso a distribuição de outros para verificar a relevância

# %%
df['educacao'].fillna('outros', inplace=True)
df['estado_civil'].fillna('outros', inplace=True)

# %%
# verificando se existem nulos
tot_nulos =str(df.isnull().sum().sum())
display(HTML(f'<h5> A quantiodade total de nulos do data frame é: <span style="color:red">{tot_nulos}</span> registros.</h5>'))
# Out:
# <h5> A quantiodade total de nulos do data frame é: <span style="color:red">0</span> registros.</h5>

# %% [markdown]
# ___________
# ### 9 Análise Gráfica
# #### 9.1 Qual a distribuição das variáveis Nominais?

# %%
sns.set_style('darkgrid')
ax = sns.countplot( data=df, x='educacao', palette='coolwarm')
ax.figure.set_size_inches(12, 8)
total = float(sum([p.get_height() for p in ax.patches]))
for p in ax.patches:
    valores = "{0}\n{1:.2f}%".format(f'{p.get_height():_.2f}'.replace('.',',').replace('_','.')[:-3],100 * p.get_height()/total)
    x = p.get_x() + p.get_width()/2
    y = p.get_height() /2
    ax.annotate(valores, (x, y),ha='center')
plt.suptitle('Distribuição por Educação', fontsize=22)
plt.ylabel('Quantidade', size=14)
plt.xlabel('Educação', size=14)
plt.show()

# %%
sns.set_style('darkgrid')
ax = sns.barplot( data=df, x="educacao", y="limite", palette='coolwarm', estimator= np.sum)
ax.figure.set_size_inches(12, 8)
total = float(sum([p.get_height() for p in ax.patches]))
for p in ax.patches:
    valores = "{0}\n{1:.2f}%".format(f'{p.get_height():_.2f}'.replace('.',',').replace('_','.')[:-3],100 * p.get_height()/total)
    x = p.get_x() + p.get_width()/2
    y = p.get_height() /2
    ax.annotate(valores, (x, y),ha='center')
plt.ticklabel_format(style='plain', axis='y',useOffset=False)
plt.suptitle('Soma dos limites por Educação', fontsize=22)
plt.ylabel('Soma Limites', size=14)
plt.xlabel('Educação', size=14)
plt.show()

# %%
sns.set_style('darkgrid')
ax = sns.barplot( data=df, x="educacao", y="limite", hue='sexo', palette='coolwarm', estimator=np.sum)
ax.figure.set_size_inches(12, 8)
total = float(sum([p.get_height() for p in ax.patches]))
for p in ax.patches:
    valores = "{0}\n{1:.2f}%".format(f'{p.get_height():_.2f}'.replace('.',',').replace('_','.')[:-3],100 * p.get_height()/total)
    x = p.get_x() + p.get_width()/2
    y = p.get_height() /2
    ax.annotate(valores, (x, y),ha='center')
plt.ticklabel_format(style='plain', axis='y',useOffset=False)
plt.suptitle('Soma dos limites por Educação e Sexo', fontsize=22)
plt.ylabel('Soma Limites', size=14)
plt.xlabel('Educação', size=14)
plt.show()

# %%
sns.set_style('darkgrid')
ax = sns.countplot( data=df, x='sexo', palette='coolwarm')
ax.figure.set_size_inches(12, 8)
total = float(sum([p.get_height() for p in ax.patches]))
for p in ax.patches:
    valores = "{0}\n{1:.2f}%".format(f'{p.get_height():_.2f}'.replace('.',',').replace('_','.')[:-3],100 * p.get_height()/total)
    x = p.get_x() + p.get_width()/2
    y = p.get_height() /2
    ax.annotate(valores, (x, y),ha='center')
plt.ticklabel_format(style='plain', axis='y',useOffset=False)
plt.suptitle('Distribuição por Sexo', fontsize=22)
plt.ylabel('Quantidade', size=14)
plt.xlabel('Sexo', size=14)
plt.show()

# %%
sns.set_style('darkgrid')
ax = sns.barplot( data=df, x="sexo", y="limite", palette='coolwarm', estimator= np.sum)
ax.figure.set_size_inches(12, 8)
total = float(sum([p.get_height() for p in ax.patches]))
for p in ax.patches:
    valores = "{0}\n{1:.2f}%".format(f'{p.get_height():_.2f}'.replace('.',',').replace('_','.')[:-3],100 * p.get_height()/total)
    x = p.get_x() + p.get_width()/2
    y = p.get_height() /2
    ax.annotate(valores, (x, y),ha='center')
plt.ticklabel_format(style='plain', axis='y',useOffset=False)
plt.suptitle('Soma dos limites por Sexo', fontsize=22)
plt.ylabel('Soma Limites', size=14)
plt.xlabel('sexo', size=14)
plt.show()

# %%
sns.set_style('darkgrid')
ax = sns.countplot( data=df, x='estado_civil', palette='coolwarm')
ax.figure.set_size_inches(12, 8)
total = float(sum([p.get_height() for p in ax.patches]))
for p in ax.patches:
    valores = "{0}\n{1:.2f}%".format(f'{p.get_height():_.2f}'.replace('.',',').replace('_','.')[:-3],100 * p.get_height()/total)
    x = p.get_x() + p.get_width()/2
    y = p.get_height() /2
    ax.annotate(valores, (x, y),ha='center')
plt.suptitle('Distribuição por estado_civil', fontsize=22)
plt.ylabel('Quantidade', size=14)
plt.xlabel('estado_civil', size=14)
plt.show()

# %% [markdown]
#  * Mesmo após unir os nulos gerados durante a categorização das variáveis estado civil e educação os valores de "outros", destas variáveis continuam pouco significativa:
#  1,26% em estado civil e
#  1,56% em educação.

# %%
sns.set_style('darkgrid')
ax = sns.barplot( data=df, x="estado_civil", y="limite", palette='coolwarm', estimator= np.sum)
ax.figure.set_size_inches(12, 8)
total = float(sum([p.get_height() for p in ax.patches]))
for p in ax.patches:
    valores = "{0}\n{1:.2f}%".format(f'{p.get_height():_.2f}'.replace('.',',').replace('_','.')[:-3],100 * p.get_height()/total)
    x = p.get_x() + p.get_width()/2
    y = p.get_height() /2
    ax.annotate(valores, (x, y),ha='center')
plt.ticklabel_format(style='plain', axis='y',useOffset=False)
plt.suptitle('Soma dos limites por Estado Civil', fontsize=22)
plt.ylabel('Soma Limites', size=14)
plt.xlabel('Estado Civil', size=14)
plt.show()

# %%
sns.set_style('darkgrid')
ax = sns.barplot( data=df, x="estado_civil",hue='sexo', y="limite", palette='coolwarm', estimator= np.sum)
ax.figure.set_size_inches(12, 8)
total = float(sum([p.get_height() for p in ax.patches]))
for p in ax.patches:
    valores = "{0}\n{1:.2f}%".format(f'{p.get_height():_.2f}'.replace('.',',').replace('_','.')[:-3],100 * p.get_height()/total)
    x = p.get_x() + p.get_width()/2
    y = p.get_height() /2
    ax.annotate(valores, (x, y),ha='center')
plt.ticklabel_format(style='plain', axis='y',useOffset=False)
plt.suptitle('Soma dos limites por Estado Civil e Sexo', fontsize=22)
plt.ylabel('Soma Limites', size=14)
plt.xlabel('Estado Civil', size=14)
plt.show()

# %% [markdown]
# #### 9.2 Qual a distribuição das demais variáveis?

# %%
plt.figure(figsize=(12,8))
sns.histplot(data=df, x="idade",bins=58 ,kde=True, color='lightsteelblue', edgecolor='white',)
plt.suptitle('Distribuição por Idade', fontsize=22)
plt.ylabel('Quantidade', size=14)
plt.xlabel('Idade', size=14)
plt.show()

# %% [markdown]
# * Durante a analize através do Pandas profiling, foi verificado picos no histograma de Idade.
# a mudança de bins mostrou a real situação:

# %%
df.groupby('idade')['limite'].count().to_frame(name='Quantidades').style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_e230d_row0_col0, #T_e230d_row39_col0 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_e230d_row1_col0 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_e230d_row2_col0 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_e230d_row3_col0 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_e230d_row4_col0 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_e230d_row5_col0 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_e230d_row6_col0 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_e230d_row7_col0 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_e230d_row8_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_e230d_row9_col0 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_e230d_row10_col0 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_e230d_row11_col0 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_e230d_row12_col0 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_e230d_row13_col0 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_e230d_row14_col0 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_e230d_row15_col0 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_e230d_row16_col0 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_e230d_row17_col0 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_e230d_row18_col0 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_e230d_row19_col0 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_e230d_row20_col0 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_e230d_row21_col0 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_e230d_row22_col0 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_e230d_row23_col0 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_e230d_row24_col0 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_e230d_row25_col0 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_e230d_row26_col0 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_e230d_row27_col0 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_e230d_row28_col0 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_e230d_row29_col0 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_e230d_row30_col0 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_e230d_row31_col0 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_e230d_row32_col0 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_e230d_row33_col0 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_e230d_row34_col0 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_e230d_row35_col0 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_e230d_row36_col0, #T_e230d_row37_col0 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_e230d_row38_col0 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_e230d_row40_col0 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_e230d_row41_col0 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_e230d_row42_col0, #T_e230d_row43_col0 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_e230d_row44_col0, #T_e230d_row45_col0 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_e230d_row46_col0, #T_e230d_row48_col0 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_e230d_row47_col0, #T_e230d_row50_col0, #T_e230d_row51_col0, #T_e230d_row52_col0, #T_e230d_row53_col0, #T_e230d_row54_col0, #T_e230d_row55_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_e230d_row49_col0 {
#   background-color: #f6faff;
#   color: #000000;
# }
# </style>
# <table id="T_e230d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e230d_level0_col0" class="col_heading level0 col0" >Quantidades</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >idade</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e230d_level0_row0" class="row_heading level0 row0" >21</th>
#       <td id="T_e230d_row0_col0" class="data row0 col0" >67</td>
#     </tr>
#     <tr>
#       <th id="T_e230d_level0_row1" class="row_heading level0 row1" >22</th>
#       <td id="T_e230d_row1_col0" class="data row1 col0" >560</td>
#     </tr>
#     <tr>
#       <th id="T_e230d_level0_row2" class="row_heading level0 row2" >23</th>
#       <td id="T_e230d_row2_col0" class="data row2 col0" >931</td>
#     </tr>
#     <tr>
#       <th id="T_e230d_level0_row3" class="row_heading level0 row3" >24</th>
#       <td id="T_e230d_row3_col0" class="data row3 col0" >1127</td>
#     </tr>
#     <tr>
#       <th id="T_e230d_level0_row4" class="row_heading level0 row4" >25</th>
#       <td id="T_e230d_row4_col0" class="data row4 col0" >1186</td>
#     </tr>
#     <tr>
#       <th id="T_e230d_level0_row5" class="row_heading level0 row5" >26</th>
#       <td id="T_e230d_row5_col0" class="data row5 col0" >1256</td>
#     </tr>
#     <tr>
#       <th id="T_e230d_level0_row6" class="row_heading level0 row6" >27</th>
#       <td id="T_e230d_row6_col0" class="data row6 col0" >1477</td>
#     </tr>
#     <tr>
#       <th id="T_e230d_level0_row7" class="row_heading level0 row7" >28</th>
#       <td id="T_e230d_row7_col0" class="data row7 col0" >1409</td>
#     </tr>
#     <tr>
#       <th id="T_e230d_level0_row8" class="row_heading level0 row8" >29</th>
#       <td id="T_e230d_row8_col0" class="data row8 col0" >1605</td>
#     </tr>
#     <tr>
#       <th id="T_e230d_level0_row9" class="row_heading level0 row9" >30</th>
#       <td id="T_e230d_row9_col0" class="data row9 col0" >1395</td>
#     </tr>
#     <tr>
#       <th id="T_e230d_level0_row10" class="row_heading level0 row10" >31</th>
#       <td id="T_e230d_row10_col0" class="data row10 col0" >1217</td>
#     </tr>
#     <tr>
#       <th id="T_e230d_level0_row11" class="row_heading level0 row11" >32</th>
#       <td id="T_e230d_row11_col0" class="data row11 col0" >1158</td>
#     </tr>
#     <tr>
#       <th id="T_e230d_level0_row12" class="row_heading level0 row12" >33</th>
#       <td id="T_e230d_row12_col0" class="data row12 col0" >1146</td>
#     </tr>
#     <tr>
#       <th id="T_e230d_level0_row13" class="row_heading level0 row13" >34</th>
#       <td id="T_e230d_row13_col0" class="data row13 col0" >1162</td>
#     </tr>
#     <tr>
#       <th id="T_e230d_level0_row14" class="row_heading level0 row14" >35</th>
#       <td id="T_e230d_row14_col0" class="data row14 col0" >1113</td>
#     </tr>
#     <tr>
#       <th id="T_e230d_level0_row15" class="row_heading level0 row15" >36</th>
#       <td id="T_e230d_row15_col0" class="data row15 col0" >1108</td>
#     </tr>
#     <tr>
#       <th id="T_e230d_level0_row16" class="row_heading level0 row16" >37</th>
#       <td id="T_e230d_row16_col0" class="data row16 col0" >1041</td>
#     </tr>
#     <tr>
#       <th id="T_e230d_level0_row17" class="row_heading level0 row17" >38</th>
#       <td id="T_e230d_row17_col0" class="data row17 col0" >944</td>
#     </tr>
#     <tr>
#       <th id="T_e230d_level0_row18" class="row_heading level0 row18" >39</th>
#       <td id="T_e230d_row18_col0" class="data row18 col0" >954</td>
#     </tr>
#     <tr>
#       <th id="T_e230d_level0_row19" class="row_heading level0 row19" >40</th>
#       <td id="T_e230d_row19_col0" class="data row19 col0" >870</td>
#     </tr>
#     <tr>
#       <th id="T_e230d_level0_row20" class="row_heading level0 row20" >41</th>
#       <td id="T_e230d_row20_col0" class="data row20 col0" >824</td>
#     </tr>
#     <tr>
#       <th id="T_e230d_level0_row21" class="row_heading level0 row21" >42</th>
#       <td id="T_e230d_row21_col0" class="data row21 col0" >794</td>
#     </tr>
#     <tr>
#       <th id="T_e230d_level0_row22" class="row_heading level0 row22" >43</th>
#       <td id="T_e230d_row22_col0" class="data row22 col0" >670</td>
#     </tr>
#     <tr>
#       <th id="T_e230d_level0_row23" class="row_heading level0 row23" >44</th>
#       <td id="T_e230d_row23_col0" class="data row23 col0" >700</td>
#     </tr>
#     <tr>
#       <th id="T_e230d_level0_row24" class="row_heading level0 row24" >45</th>
#       <td id="T_e230d_row24_col0" class="data row24 col0" >617</td>
#     </tr>
#     <tr>
#       <th id="T_e230d_level0_row25" class="row_heading level0 row25" >46</th>
#       <td id="T_e230d_row25_col0" class="data row25 col0"

# %%
df.groupby('idade')['limite'].count().to_frame(name='Quantidades').style.bar( color='lightsteelblue')
# Out:
# <style type="text/css">
# #T_c080e_row0_col0, #T_c080e_row39_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 4.2%, transparent 4.2%);
# }
# #T_c080e_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 34.9%, transparent 34.9%);
# }
# #T_c080e_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 58.0%, transparent 58.0%);
# }
# #T_c080e_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 70.2%, transparent 70.2%);
# }
# #T_c080e_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 73.9%, transparent 73.9%);
# }
# #T_c080e_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 78.3%, transparent 78.3%);
# }
# #T_c080e_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 92.0%, transparent 92.0%);
# }
# #T_c080e_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 87.8%, transparent 87.8%);
# }
# #T_c080e_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 100.0%, transparent 100.0%);
# }
# #T_c080e_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 86.9%, transparent 86.9%);
# }
# #T_c080e_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 75.8%, transparent 75.8%);
# }
# #T_c080e_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 72.1%, transparent 72.1%);
# }
# #T_c080e_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 71.4%, transparent 71.4%);
# }
# #T_c080e_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 72.4%, transparent 72.4%);
# }
# #T_c080e_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 69.3%, transparent 69.3%);
# }
# #T_c080e_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 69.0%, transparent 69.0%);
# }
# #T_c080e_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 64.9%, transparent 64.9%);
# }
# #T_c080e_row17_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 58.8%, transparent 58.8%);
# }
# #T_c080e_row18_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 59.4%, transparent 59.4%);
# }
# #T_c080e_row19_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 54.2%, transparent 54.2%);
# }
# #T_c080e_row20_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 51.3%, transparent 51.3%);
# }
# #T_c080e_row21_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 49.5%, transparent 49.5%);
# }
# #T_c080e_row22_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 41.7%, transparent 41.7%);
# }
# #T_c080e_row23_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 43.6%, transparent 43.6%);
# }
# #T_c080e_row24_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 38.4%, transparent 38.4%);
# }
# #T_c080e_row25_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 35.5%, transparent 35.5%);
# }
# #T_c080e_row26_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 31.2%, transparent 31.2%);
# }
# #T_c080e_row27_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 29.0%, transparent 29.0%);
# }
# #T_c080e_row28_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 28.2%, transparent 28.2%);
# }
# #T_c080e_row29_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 25.6%, transparent 25.6%);
# }
# #T_c080e_row30_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 21.2%, transparent 21.2%);
# }
# #T_c080e_row31_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 18.9%, transparent 18.9%);
# }
# #T_c080e_row32_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 20.2%, transparent 20.2%);
# }
# #T_c080e_row33_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 15.4%, transparent 15.4%);
# }
# #T_c080e_row34_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 13.0%, transparent 13.0%);
# }
# #T_c080e_row35_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 11.1%, transparent 11.1%);
# }
# #T_c080e_row36_col0, #T_c080e_row37_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 7.6%, transparent 7.6%);
# }
# #T_c080e_row38_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 5.2%, transparent 5.2%);
# }
# #T_c080e_row40_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 3.5%, transparent 3.5%);
# }
# #T_c080e_row41_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 2.7%, transparent 2.7%);
# }
# #T_c080e_row42_col0, #T_c080e_row43_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 1.9%, transparent 1.9%);
# }
# #T_c080e_row44_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 1.5%, transparent 1.5%);
# }
# #T_c080e_row45_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 1.6%, transparent 1.6%);
# }
# #T_c080e_row46_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 1.0%, transparent 1.0%);
# }
# #T_c080e_row47_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 0.3%, transparent 0.3%);
# }
# #T_c080e_row48_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 0.9%, transparent 0.9%);
# }
# #T_c080e_row49_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 0.6%, transparent 0.6%);
# }
# #T_c080e_row50_col0, #T_c080e_row51_col0, #T_c080e_row52_col0, #T_c080e_row54_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 0.2%, transparent 0.2%);
# }
# #T_c080e_row53_col0, #T_c080e_row55_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 0.1%, transparent 0.1%);
# }
# </style>
# <table id="T_c080e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c080e_level0_col0" class="col_heading level0 col0" >Quantidades</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >idade</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c080e_level0_row0" class="row_heading level0 row0" >21</th>
#       <td id="T_c080e_row0_col0" class="data row0 col0" >67</td>
#     </tr>
#     <tr>
#       <th id="T_c080e_level0_row1" class="row_heading level0 row1" >22</th>
#       <td id="T_c080e_row1_col0" class="data row1 col0" >560</td>
#     </tr>
#     <tr>
#       <th id="T_c080e_level0_row2" class="row_heading level0 row2" >23</th>
#       <td id="T_c080e_row2_col0" class="data row2 col0" >931</td>
#     </tr>
#     <tr>
#       <th id="T_c080e_level0_row3" class="row_heading level0 row3" >24</th>
#       <td id="T_c080e_row3_col0" class="data row3 col0" >1127</td>
#     </tr>
#     <tr>
#       <th id="T_c080e_level0_row4" class="row_heading level0 row4" >25</th>
#       <td id="T_c080e_row4_col0" class="data row4 col0" >1186</td>
#     </tr>
#     <tr>
#       <th id="T_c080e_level0_row5" class="row_heading level0 row5" >26</th>
#       <td id="T_c080e_row5_col0" class="data row5 col0" >1256</td>
#     </tr>
#     <tr>
#       <th id="T_c080e_level0_row6" class="row_heading level0 row6" >27</th>
#       <td id="T_c080e_row6_col0" class="data row6 col0" >1477</td>
#     </tr>
#     <tr>
#       <th id="T_c080e_level0_row7" class="row_heading level0 row7" >28</th>
#       <td id="T_c080e_row7_col0" class="data row7 col0" >1409</td>
#     </tr>
#     <tr>
#       <th id="T_c080e_level0_row8" class="row_heading level0 row8" >29</th>
#       <td id="T_c080e_row8_col0" class="data row8 col0" >1605</td>
#     </tr>
#     <tr>
#       <th id="T_c080e_level0_row9" class="row_heading level0 row9" >30</th>
#       <td id="T_c080e_row9_col0" class="data row9 col0" >1395</td>
#     </tr>
#     <tr>
#       <th id="T_c080e_level0_row10" class="row_heading level0 row10" >31</th>
#       <td id="T_c080e_row10_col0" class="data row10 col0" >121

# %%
plt.figure(figsize=(12,8))
sns.histplot(data=df, x="limite",bins=30 ,kde=True,color='lightsteelblue', edgecolor='white',)
plt.ticklabel_format(style='plain', axis='x',useOffset=False)
plt.suptitle('Distribuição dos limites', fontsize=22)
plt.ylabel('Quantidade', size=14)
plt.xlabel('Limites', size=14)
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.ticklabel_format(style='plain', axis='y',useOffset=False)
box_plot = sns.boxplot(y="limite",
                       x='sexo',
                       palette='Blues', 
                       data=df) 
ax = box_plot.axes
lines = ax.get_lines()
categories = ax.get_xticks()
for cat in categories:
    # every 4th line at the interval of 6 is median line
    # 0 -> p25 1 -> p75 2 -> lower whisker 3 -> upper whisker 4 -> p50 5 -> upper extreme value
    y = round(lines[4+cat*6].get_ydata()[0],1) 
    ax.text(
        cat, 
        y, 
        f'{y}', 
        ha='center', 
        va='center', 
        fontweight='bold', 
        size=10,
        color='white',
        bbox=dict(facecolor='#445A64'))

box_plot.figure.tight_layout()
plt.suptitle('Limites', fontsize=22)
plt.ylabel('Valor', size=14)
plt.xlabel('Estado Civil', size=14)
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.ticklabel_format(style='plain', axis='y',useOffset=False)
box_plot = sns.boxplot(y="limite",
                       x='estado_civil',
                       palette='Blues', 
                       data=df) 
ax = box_plot.axes
lines = ax.get_lines()
categories = ax.get_xticks()
for cat in categories:
    # every 4th line at the interval of 6 is median line
    # 0 -> p25 1 -> p75 2 -> lower whisker 3 -> upper whisker 4 -> p50 5 -> upper extreme value
    y = round(lines[4+cat*6].get_ydata()[0],1) 
    ax.text(
        cat, 
        y, 
        f'{y}', 
        ha='center', 
        va='center', 
        fontweight='bold', 
        size=10,
        color='white',
        bbox=dict(facecolor='#445A64'))

box_plot.figure.tight_layout()
plt.suptitle('Limites', fontsize=22)
plt.ylabel('Valor', size=14)
plt.xlabel('Estado Civil', size=14)
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.ticklabel_format(style='plain', axis='y',useOffset=False)
box_plot = sns.boxplot(y="limite",
                       x='educacao',
                       palette='Blues', 
                       data=df) 
ax = box_plot.axes
lines = ax.get_lines()
categories = ax.get_xticks()
for cat in categories:
    # every 4th line at the interval of 6 is median line
    # 0 -> p25 1 -> p75 2 -> lower whisker 3 -> upper whisker 4 -> p50 5 -> upper extreme value
    y = round(lines[4+cat*6].get_ydata()[0],1) 
    ax.text(
        cat, 
        y, 
        f'{y}', 
        ha='center', 
        va='center', 
        fontweight='bold', 
        size=10,
        color='white',
        bbox=dict(facecolor='#445A64'))

box_plot.figure.tight_layout()
plt.suptitle('Limites', fontsize=22)
plt.ylabel('Valor', size=14)
plt.xlabel('Estado Civil', size=14)
plt.show()

# %%
df.hist(bins=50, figsize=(18,12))
plt.ticklabel_format(style='plain', axis='x',useOffset=False)
plt.show()

# %%
pieces = []
for col in df.columns[df.columns.str.startswith('status_')]:
    tmp_series = df[col].value_counts()
    tmp_series.name = col
    pieces.append(tmp_series)
df_value_counts = pd.concat(pieces, axis=1)

# %%
df_value_counts.sort_index().sort_index(axis=1).plot.bar(figsize=(12,8), 
                                                         #stacked=True, 
                                                         colormap='Blues')
plt.suptitle('Distribuição dos Stastus de pagamento ao longo dos seis meses', fontsize=22)
plt.ylabel('Quantidade', size=14)
plt.xlabel('Status', size=14)
plt.show()

# %%
df_value_counts.sort_index().T.sort_index().style.bar(color='lightsteelblue').format("{:.0f}")
# Out:
# <style type="text/css">
# #T_c1bc0_row0_col0, #T_c1bc0_row1_col2, #T_c1bc0_row1_col9, #T_c1bc0_row2_col7, #T_c1bc0_row2_col9, #T_c1bc0_row3_col8, #T_c1bc0_row4_col1, #T_c1bc0_row4_col4, #T_c1bc0_row4_col5, #T_c1bc0_row4_col6, #T_c1bc0_row5_col3, #T_c1bc0_row5_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 100.0%, transparent 100.0%);
# }
# #T_c1bc0_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 94.9%, transparent 94.9%);
# }
# #T_c1bc0_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 96.1%, transparent 96.1%);
# }
# #T_c1bc0_row0_col3, #T_c1bc0_row1_col3 {
#   width: 10em;
# }
# #T_c1bc0_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 70.4%, transparent 70.4%);
# }
# #T_c1bc0_row0_col5, #T_c1bc0_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 56.4%, transparent 56.4%);
# }
# #T_c1bc0_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 49.5%, transparent 49.5%);
# }
# #T_c1bc0_row0_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 37.1%, transparent 37.1%);
# }
# #T_c1bc0_row0_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 82.6%, transparent 82.6%);
# }
# #T_c1bc0_row0_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 79.3%, transparent 79.3%);
# }
# #T_c1bc0_row0_col10, #T_c1bc0_row2_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 10.5%, transparent 10.5%);
# }
# #T_c1bc0_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 92.9%, transparent 92.9%);
# }
# #T_c1bc0_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 91.6%, transparent 91.6%);
# }
# #T_c1bc0_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 66.9%, transparent 66.9%);
# }
# #T_c1bc0_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 54.6%, transparent 54.6%);
# }
# #T_c1bc0_row1_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 84.8%, transparent 84.8%);
# }
# #T_c1bc0_row1_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 48.6%, transparent 48.6%);
# }
# #T_c1bc0_row1_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 17.4%, transparent 17.4%);
# }
# #T_c1bc0_row1_col10, #T_c1bc0_row4_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 5.3%, transparent 5.3%);
# }
# #T_c1bc0_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 88.8%, transparent 88.8%);
# }
# #T_c1bc0_row2_col1, #T_c1bc0_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 94.0%, transparent 94.0%);
# }
# #T_c1bc0_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 97.1%, transparent 97.1%);
# }
# #T_c1bc0_row2_col3, #T_c1bc0_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 0.1%, transparent 0.1%);
# }
# #T_c1bc0_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 80.4%, transparent 80.4%);
# }
# #T_c1bc0_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 55.2%, transparent 55.2%);
# }
# #T_c1bc0_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 69.7%, transparent 69.7%);
# }
# #T_c1bc0_row2_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 21.7%, transparent 21.7%);
# }
# #T_c1bc0_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 83.5%, transparent 83.5%);
# }
# #T_c1bc0_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 98.1%, transparent 98.1%);
# }
# #T_c1bc0_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 93.0%, transparent 93.0%);
# }
# #T_c1bc0_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 97.2%, transparent 97.2%);
# }
# #T_c1bc0_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 73.6%, transparent 73.6%);
# }
# #T_c1bc0_row3_col6, #T_c1bc0_row5_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 76.8%, transparent 76.8%);
# }
# #T_c1bc0_row3_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 60.0%, transparent 60.0%);
# }
# #T_c1bc0_row3_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 46.6%, transparent 46.6%);
# }
# #T_c1bc0_row3_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 15.8%, transparent 15.8%);
# }
# #T_c1bc0_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 77.3%, transparent 77.3%);
# }
# #T_c1bc0_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 92.8%, transparent 92.8%);
# }
# #T_c1bc0_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 0.8%, transparent 0.8%);
# }
# #T_c1bc0_row4_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 71.4%, transparent 71.4%);
# }
# #T_c1bc0_row4_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 52.2%, transparent 52.2%);
# }
# #T_c1bc0_row4_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 34.5%, transparent 34.5%);
# }
# #T_c1bc0_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 87.0%, transparent 87.0%);
# }
# #T_c1bc0_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 67.9%, transparent 67.9%);
# }
# #T_c1bc0_row5_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 98.8%, transparent 98.8%);
# }
# #T_c1bc0_row5_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 74.3%, transparent 74.3%);
# }
# #T_c1bc0_row5_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 47.8%, transparent 47.8%);
# }
# #T_c1bc0_row5_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, lightsteelblue 15.5%, transparent 15.5%);
# }
# </style>
# <table id="T_c1bc0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1bc0_level0_col0" class="col_heading level0 col0" >-2</th>
#       <th id="T_c1bc0_level0_col1" class="col_heading level0 col1" >-1</th>
#       <th id="T_c1bc0_level0_col2" class="col_heading level0 col2" >0</th>
#       <th id="T_c1bc0_level0_col3" class="col_heading level0 col3" >1</th>
#       <th id="T_c1bc0_level0_col4" class="col_heading level0 col4" >2</th>
#       <th id="T_c1bc0_level0_col5" class="col_heading level0 col5" >3</th>
#       <th id="T_c1bc0_level0_col6" class="col_heading level0 col6" >4</th>
#       <th id="T_c1bc0_level0_col7" class="col_heading level0 col7" >5</th>
#       <th id="T_c1bc0_level0_col8" class="col_heading level0 col8" >6</th>
#       <th id="T_c1bc0_level0_col9" class="col_heading level0 col9" >7</th>
#       <th id="T_c1bc0_level0_col10" class="col_heading level0 col10" >8</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1bc0_level0_row0" class="row_heading level0 row0" >status_0504</th>
#       <td id="T_c1bc0_row0_col0" class="data row0 col0" >4895</td>
#       <td id="T_c1bc0_row0_col1" class="data row0 col1" >5740</td>
#       <td id="T_c1bc0_row0_col2" class="data row0 col2" >16286</td>
#       <td id="T_c1bc0_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_c1bc0_row0_col4" class="data row0 col4" >2766</td>
#       <td id="T_c1bc0_row0_col5" class="data row0 col5" >184</td>
#       <td id="T_c1bc0_row0_col6" class="data row0 col6" >49</td>
#       <td id="T_c1bc0_row0_col7" class="data row0 col7" >13</td>
#       <td id="T_c1bc0_row0_col8" class="data row0 col8" >19</td>
#       <td id="T_c1bc0_row0_col9" class="data row0 col9" >46</td>
#       <td id="T_c1bc0_row0_col10" class="data row0 col10" >2</td>
#     </tr>
#     <tr>
#       <th id="T_c1bc0_level0_row1" class="row_heading level0 row1" >status_0505</th>
#       <td id="T_c1bc0_row1_col0" class="data row1 col0" >4546</td>
#       <td id="T_c1bc0_row1_col1" class="data row1 col1" >5539</td>
#       <td id="T_c1bc0_row1_col2" class="data row1 col2" >16947</t

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 8))

_ = df[[col for col in df if col.startswith('status_')]].hist(bins=30, color='lightsteelblue', edgecolor='white', linewidth=1.0,
           xlabelsize=8, ylabelsize=8, grid=False, ax=ax)  
ax.ticklabel_format(useOffset=False, style='plain', axis='both')
plt.suptitle('Distribuição dos Status de pagamento', fontsize=22)
plt.tight_layout()   
plt.show()
# Out:
# /tmp/ipykernel_14076/3797600517.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   _ = df[[col for col in df if col.startswith('status_')]].hist(bins=30, color='lightsteelblue', edgecolor='white', linewidth=1.0,

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 8))

_ = df[[col for col in df if col.startswith('saldo_')]].hist(bins=30, color='lightsteelblue', edgecolor='white', linewidth=1.0,
           xlabelsize=8, ylabelsize=8, grid=False, ax=ax)    
ax.ticklabel_format(useOffset=False, style='plain', axis='both')
plt.ticklabel_format(style='plain', axis='x',useOffset=False)
plt.suptitle('Distribuição dos valor de fechamento da fatura', fontsize=22)
plt.tight_layout()
# Out:
# /tmp/ipykernel_14076/623753125.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   _ = df[[col for col in df if col.startswith('saldo_')]].hist(bins=30, color='lightsteelblue', edgecolor='white', linewidth=1.0,

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 8))

_ = df[[col for col in df if col.startswith('pago_')]].hist(bins=30, color='lightsteelblue', edgecolor='white', linewidth=1.0,
           xlabelsize=8, ylabelsize=8, grid=False, ax=ax)    
ax.ticklabel_format(useOffset=False, style='plain', axis='both')
plt.ticklabel_format(style='plain', axis='x',useOffset=False)
plt.suptitle('Distribuição do valor pago no mês anterior', fontsize=22)
plt.tight_layout()
# Out:
# /tmp/ipykernel_14076/1498778660.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   _ = df[[col for col in df if col.startswith('pago_')]].hist(bins=30, color='lightsteelblue', edgecolor='white', linewidth=1.0,

# %% [markdown]
# ______________
# ### 10 Qual é o Predito e quais são os candidatos a preditores?

# %%
predito = 'mau'
prediotres = df.columns[:-1]

# %%
display(HTML(f'<h5> O predito, alvo ou target é a variável: <span style="color:red">{predito}</span>.</h5>'))
# Out:
# <h5> O predito, alvo ou target é a variável: <span style="color:red">mau</span>.</h5>

# %%
prediotres.to_frame(name='Preditores').reset_index(drop=True)
# Out:
#       Preditores
# 0         limite
# 1           sexo
# 2       educacao
# 3   estado_civil
# 4          idade
# 5    status_0509
# 6    status_0508
# 7    status_0507
# 8    status_0506
# 9    status_0505
# 10   status_0504
# 11    saldo_0509
# 12    saldo_0508
# 13    saldo_0507
# 14    saldo_0506
# 15    saldo_0505
# 16    saldo_0504
# 17     pago_0509
# 18     pago_0508
# 19     pago_0507
# 20     pago_0506
# 21     pago_0505
# 22     pago_0504

# %% [markdown]
# ___________
# ### 11 Os dados estão balanceados?

# %%
sns.set_style('darkgrid')
ax = sns.countplot( data=df, x='mau', palette='coolwarm')
ax.figure.set_size_inches(12, 8)
total = float(len(df))
for p in ax.patches:
    valores = "{0}\n{1:.2f}%".format(f'{p.get_height():_.2f}'.replace('.',',').replace('_','.')[:-3],100 * p.get_height()/total)
    x = p.get_x() + p.get_width()/2
    y = p.get_height()/2
    ax.annotate(valores, (x, y),ha='center')
plt.suptitle('Distribuição do Predito', fontsize=22)
plt.ylabel('Quantidade', size=14)
plt.xlabel('Mau', size=14)
plt.show()

# %%
display(HTML(f'<h5> O Grafico acima mostra que os dados <span style="color:red">não</span> estão balenceados.</h5>'))
# Out:
# <h5> O Grafico acima mostra que os dados <span style="color:red">não</span> estão balenceados.</h5>

# %% [markdown]
# ### 12 Salvamento dos dados pré processados

# %%
df.to_csv("../data/interim/data_pre_processados.csv", index=False)

# %% [markdown]
# ### 13 Insights

# %% [markdown]
# #### Após a analise dos dados chegamos as seguintes constatações:
#
#  * Os dados não estão balanceados com relação ao predito
#  * Os dados descritos na legenda original do conjunto de dados não englobavam todos os ranges dos itens relacionados na base, assim foi adequado unificar os valores que estavam fora da classificação da legenda original em uma categoria chamada outros, tendo o impacto na análise dos dados de forma ínfima, sendo menor que 2% no caso da categoria educação 1,56% e 1,26% na categoria estado civil.
#  * As variáveios de estatus apresentavam os valores -2  0 que não estavam na documentação, em pesquisa na literatura encontramos que -2 refere-se a fatura fechada com valor Zero e o marca o cliente que pagou um valor menor que o valor de fechamento da fatura.
#  * A maoipr parte das concessões de cartões de crédito foram para coleites com nível superior e pós-graduação.
#  * O publico feminino detem a maioria dos cartões.
#  * A faixa etária com mais cartões é entre 25 e 35 anos.
#  * Temos uma maior quantodade de pequenos limites distribuidos, quanto maior o limite menos concessões foram feitas.
